# %%
from PIL import Image
import IPython.display as display
img = Image.open('Bahdanau.png')
display.display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=409x871>

# %%
from PIL import Image
import IPython.display as display
img = Image.open('缩放点积自注意力.png')
display.display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=551x651>

# %%
from PIL import Image
import IPython.display as display
img = Image.open('Inception.png')
display.display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=611x450>
