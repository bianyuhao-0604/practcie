# %%
users = {"Alice": 25, "Bob": 30}
print(users.get('Alice'))
print(users.get('zsa',13))
# Out:
# 25
# 13

# %%
profile = {}
profile['sdna']=99
print(profile)
profile['sdna']=20
print(profile)
del profile['sdna']
print(profile)
# Out:
# {'sdna': 99}
# {'sdna': 20}
# {}

# %%
raw_list = [1,2,2,3,4,4,5]
unique_list = list(set(raw_list))
print(unique_list)
# Out:
# [1, 2, 3, 4, 5]

# %%
apple_fans = {"Alice", "Bob", "Charlie"}
banana_fans = {"Bob", "David", "Eve"}
both = apple_fans & banana_fans
print(both)
either = apple_fans | banana_fans
print(either)
# Out:
# {'Bob'}
# {'Charlie', 'Eve', 'David', 'Bob', 'Alice'}

# %%
products = {"Apple": 5, "Banana": 3, "Orange": 4}
for name,price in products.items():
    print(f'商品:{name},价格{price}元')
# Out:
# 商品:Apple,价格5元
# 商品:Banana,价格3元
# 商品:Orange,价格4元

# %%
import sys
d = {}
for i in range(10):
    d[f'key_{i}'] = i
print(list(d.keys()))
big_dict = {i:i for i in range(10000)}
big_list = list(range(10000))
print(sys.getsizeof(big_dict))
print(sys.getsizeof(big_list))
# Out:
# ['key_0', 'key_1', 'key_2', 'key_3', 'key_4', 'key_5', 'key_6', 'key_7', 'key_8', 'key_9']
# 294992
# 80056
