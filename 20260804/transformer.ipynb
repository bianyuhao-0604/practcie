# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
D = 512
H = 8
DK = D // H
FF = 2048
N = 6
ZH = {'<pad>':0,'<bos>':1,'<eos>':2,'我':3,'爱':4,'机器':5,'学习':6,'你':7,'好':8}
EN = {'<pad>':0,'<bos>':1,'<eos>':2,'I':3,'love':4,'machine':5,'learning':6,'you':7,'hello':8}
V_ZH,V_EN = len(ZH),len(EN)
PAD,BOS,EOS = 0,1,2
import IPython.display as display
from PIL import Image
img = Image.open('transformer.drawio.png')
display.display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=262x752>
