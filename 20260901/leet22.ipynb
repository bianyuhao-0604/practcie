# %%
#给定一个已排序的链表的头 head ， 删除所有重复的元素，使每个元素只出现一次 。返回 已排序的链表 。
#输入：head = [1,1,2]
#输出：[1,2]
#输入：head = [1,1,2,3,3]
#输出：[1,2,3]
from typing import Optional
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
def build_linked_list(vals):
    if not vals:
        return None
    head = ListNode(vals[0])
    cur = head
    for val in vals[1:]:
        cur.next = ListNode(val)
        cur = cur.next
    return head
class Solution:
    def deleteDuplicates(self, head: Optional[ListNode]) -> Optional[ListNode]:
        if head is None:
            return None
        cur = head
        while cur.next:
            if cur.val == cur.next.val:
                cur.next = cur.next.next
            else:
                cur = cur.next
        return head
def print_list(head):
    cur = head
    while cur:
        print(cur.val, end=" -> " if cur.next else "\n")
        cur = cur.next
head = build_linked_list([1,1,2,3,3])
s = Solution()
print_list(s.deleteDuplicates(head))
# Out:
# 1 -> 2 -> 3

# %%
#给定一个二叉树 root ，返回其最大深度。
#二叉树的 最大深度 是指从根节点到最远叶子节点的最长路径上的节点数。
#输入：root = [3,9,20,null,null,15,7]
#输出：3
#输入：root = [1,null,2]
#输出：2
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right
class Solution:
    def maxDepth(self, root: Optional[TreeNode]) -> int:
        if root is None:
            return 0
        left_depth = self.maxDepth(root.left)
        right_depth = self.maxDepth(root.right)
        return max(left_depth,right_depth)+1
s = Solution()
root = TreeNode(3)
root.left = TreeNode(9)
root.right = TreeNode(20)
root.right.left = TreeNode(15)
root.right.right = TreeNode(7)
print(s.maxDepth(root))
# Out:
# 3

# %%
import numpy as np

for split in ["train", "val", "test"]:
    path = f"D:/PPI_prediction_study-master/data/ppi_{split}.npz"
    data = np.load(path)
    X, y = data['X'], data['y']
    print(f"--- {split} ---")
    print(f"X 形状: {X.shape}")
    print(f"y 形状: {y.shape}")
    print(f"X 数据类型: {X.dtype}, y 数据类型: {y.dtype}")
    print(f"X 前1行前5列: {X[0, :5]}")
    print(f"y 前5个: {y[:5]}")
    print()
# Out:
# --- train ---
# X 形状: (163192, 2560)
# y 形状: (163192,)
# X 数据类型: float32, y 数据类型: int64
# X 前1行前5列: [ 0.00069351 -0.04202467  0.01035461  0.05758283 -0.08347585]
# y 前5个: [0 0 0 0 1]
#
# --- val ---
# X 形状: (59260, 2560)
# y 形状: (59260,)
# X 数据类型: float32, y 数据类型: int64
# X 前1行前5列: [ 0.04693899 -0.04145016 -0.01894523 -0.04478294  0.04986677]
# y 前5个: [1 0 1 0 0]
#
# --- test ---
# X 形状: (52048, 2560)
# y 形状: (52048,)
# X 数据类型: float32, y 数据类型: int64
# X 前1行前5列: [ 0.0984202  -0.13522361 -0.05528308  0.13657661 -0.02608302]
# y 前5个: [1 1 1 1 0]

# %%
for split in ["train", "val", "test"]:
    data = np.load(f"D:/PPI_prediction_study-master/data/ppi_{split}.npz")
    y = data['y']
    unique, counts = np.unique(y, return_counts=True)
    print(f"{split} 标签分布: {dict(zip(unique, counts))}")
# Out:
# train 标签分布: {np.int64(0): np.int64(81596), np.int64(1): np.int64(81596)}
# val 标签分布: {np.int64(0): np.int64(29630), np.int64(1): np.int64(29630)}
# test 标签分布: {np.int64(0): np.int64(26024), np.int64(1): np.int64(26024)}
